# %% [markdown]
# # HEALTHCARE CENSUS

# %%
# importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
# checking libraries version

print('pandas version  : ',pd.__version__)
print('matplotlib version  : ',matplotlib.__version__)
print('seaborn version : ',sns.__version__)
print('numpy version : ',np.__version__)
# Out:
# pandas version  :  1.5.3
# matplotlib version  :  3.7.0
# seaborn version :  0.12.2
# numpy version :  1.23.5

# %% [markdown]
# # PROMBLEM STATEMENT 1(Keep the relevant data)

# %%
df = pd.read_csv('census_2011.csv', usecols=['State name', 'District name', 'Population', 'Male', 'Female', 'Literate',
                                             'Male_Literate','Female_Literate', 'Rural_Households', 'Urban_Households', 
                                             'Households', 'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50', 
                                             'Age not stated' ])

# %%
df.head()
# Out:
#           State name District name  Population      Male    Female  Literate  \
# 0  JAMMU AND KASHMIR       Kupwara    870354.0  474190.0  396164.0  439654.0
# 1  JAMMU AND KASHMIR        Badgam    753745.0       NaN  355704.0  335649.0
# 2  JAMMU AND KASHMIR   Leh(Ladakh)    133487.0   78971.0   54516.0   93770.0
# 3  JAMMU AND KASHMIR        Kargil    140802.0       NaN   63017.0       NaN
# 4  JAMMU AND KASHMIR         Punch         NaN  251899.0  224936.0  261724.0
#
#    Male_Literate  Female_Literate  Rural_Households  Urban_Households  \
# 0       282823.0         156831.0          158438.0               NaN
# 1       207741.0         127908.0          160649.0           27190.0
# 2        62834.0          30936.0           36920.0           17474.0
# 3        56301.0          29935.0           40370.0            7774.0
# 4       163333.0          98391.0          132139.0           15269.0
#
#    Households  Age_Group_0_29  Age_Group_30_49  Age_Group_50  Age not stated
# ...

# %%
df.tail()
# Out:
#                       State name              District name  Population  \
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Male_Literate  Female_Literate  \
# 635   19143.0   22673.0   36470.0        16610.0          19860.0
# 636   97809.0  102413.0  154916.0        79903.0          75013.0
# 637   20727.0       NaN   25332.0        15397.0           9935.0
# 638   54861.0   50736.0   78683.0        43186.0          35497.0
# 639  127283.0  110859.0  190266.0       105794.0          84472.0
#
#      Rural_Households  Urban_Households  Households  Age_Group_0_29  \
# ...

# %%
#shape
df.shape
# Out:
# (640, 15)

# %%
#datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State name        640 non-null    object
#  1   District name     640 non-null    object
#  2   Population        610 non-null    float64
#  3   Male              610 non-null    float64
#  4   Female            607 non-null    float64
#  5   Literate          604 non-null    float64
#  6   Male_Literate     609 non-null    float64
#  7   Female_Literate   613 non-null    float64
#  8   Rural_Households  598 non-null    float64
#  9   Urban_Households  607 non-null    float64
#  10  Households        608 non-null    float64
#  11  Age_Group_0_29    609 non-null    float64
#  12  Age_Group_30_49   610 non-null    float64
#  13  Age_Group_50      609 non-null    float64
#  14  Age not stated    605 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %%
# checkin if there are anu null values in data set
df.isnull().sum()
# Out:
# State name           0
# District name        0
# Population          30
# Male                30
# Female              33
# Literate            36
# Male_Literate       31
# Female_Literate     27
# Rural_Households    42
# Urban_Households    33
# Households          32
# Age_Group_0_29      31
# Age_Group_30_49     30
# Age_Group_50        31
# Age not stated      35
# dtype: int64

# %%
df.describe(include='all')
# Out:
#            State name District name    Population          Male        Female  \
# count             640           640  6.100000e+02  6.100000e+02  6.070000e+02
# unique             35           634           NaN           NaN           NaN
# top     UTTAR PRADESH       Raigarh           NaN           NaN           NaN
# freq               71             2           NaN           NaN           NaN
# mean              NaN           NaN  1.852620e+06  9.685726e+05  9.139882e+05
# std               NaN           NaN  1.435578e+06  7.926455e+05  7.479293e+05
# min               NaN           NaN  8.004000e+03  4.414000e+03  3.590000e+03
# 25%               NaN           NaN  8.148625e+05  4.180382e+05  3.986990e+05
# 50%               NaN           NaN  1.557367e+06  7.939620e+05  7.556020e+05
# 75%               NaN           NaN  2.565248e+06  1.318615e+06  1.253832e+06
# max               NaN           NaN  1.000978e+07  5.865078e+06  5.195070e+06
#
# ...

# %% [markdown]
# # PROBLEM STATEMENT 2(Rename the Column names)

# %%
df.head()
# Out:
#           State name District name  Population      Male    Female  Literate  \
# 0  JAMMU AND KASHMIR       Kupwara    870354.0  474190.0  396164.0  439654.0
# 1  JAMMU AND KASHMIR        Badgam    753745.0       NaN  355704.0  335649.0
# 2  JAMMU AND KASHMIR   Leh(Ladakh)    133487.0   78971.0   54516.0   93770.0
# 3  JAMMU AND KASHMIR        Kargil    140802.0       NaN   63017.0       NaN
# 4  JAMMU AND KASHMIR         Punch         NaN  251899.0  224936.0  261724.0
#
#    Male_Literate  Female_Literate  Rural_Households  Urban_Households  \
# 0       282823.0         156831.0          158438.0               NaN
# 1       207741.0         127908.0          160649.0           27190.0
# 2        62834.0          30936.0           36920.0           17474.0
# 3        56301.0          29935.0           40370.0            7774.0
# 4       163333.0          98391.0          132139.0           15269.0
#
#    Households  Age_Group_0_29  Age_Group_30_49  Age_Group_50  Age not stated
# ...

# %%
df=df.rename(columns={"State name": "State/UT", "District name":"District", "Male_Literate":"Literate_Male",
                            "Female_Literate":"Literate_Female","Rural_Households":"Households_Rural", 
                           "Urban_Households":"Households_Urban", "Age_Group_0_29":"Young_and_Adult", 
                           "Age_Group_30_49":"Middle_Aged", "Age_Group_50":"Senior_Citizen","Age not stated":"Age_Not_Stated"})

# %%
df
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %% [markdown]
# # Problem Statement 3: (Rename State/UT Names)

# %%
df['State/UT'].value_counts()
# Out:
# UTTAR PRADESH                  71
# MADHYA PRADESH                 50
# BIHAR                          38
# MAHARASHTRA                    35
# RAJASTHAN                      33
# TAMIL NADU                     32
# KARNATAKA                      30
# ORISSA                         30
# ASSAM                          27
# GUJARAT                        26
# JHARKHAND                      24
# ANDHRA PRADESH                 23
# JAMMU AND KASHMIR              22
# HARYANA                        21
# PUNJAB                         20
# WEST BENGAL                    19
# CHHATTISGARH                   18
# ARUNACHAL PRADESH              16
# KERALA                         14
# UTTARAKHAND                    13
# HIMACHAL PRADESH               12
# NAGALAND                       11
# MANIPUR                         9
# NCT OF DELHI                    9
# MIZORAM                         8
# MEGHALAYA                       7
# TRIPURA                         4
# ...

# %%
df['State/UT']=df['State/UT'].str.title().str.replace(' And ', ' and ').str.replace(' OF ', ' of ')

# %%
df['State/UT'].value_counts()
# Out:
# Uttar Pradesh                  71
# Madhya Pradesh                 50
# Bihar                          38
# Maharashtra                    35
# Rajasthan                      33
# Tamil Nadu                     32
# Karnataka                      30
# Orissa                         30
# Assam                          27
# Gujarat                        26
# Jharkhand                      24
# Andhra Pradesh                 23
# Jammu and Kashmir              22
# Haryana                        21
# Punjab                         20
# West Bengal                    19
# Chhattisgarh                   18
# Arunachal Pradesh              16
# Kerala                         14
# Uttarakhand                    13
# Himachal Pradesh               12
# Nagaland                       11
# Manipur                         9
# Nct Of Delhi                    9
# Mizoram                         8
# Meghalaya                       7
# Tripura                         4
# ...

# %% [markdown]
# # Problem Statement 4: (New State/UT formation)

# %%
df[df['State/UT']=='Andhra Pradesh']
# Out:
#            State/UT                     District  Population       Male  \
# 531  Andhra Pradesh                     Adilabad   2741239.0        NaN
# 532  Andhra Pradesh                    Nizamabad   2551335.0  1250641.0
# 533  Andhra Pradesh                   Karimnagar   3776269.0  1880800.0
# 534  Andhra Pradesh                        Medak   3033288.0  1523030.0
# 535  Andhra Pradesh                    Hyderabad   3943323.0  2018575.0
# 536  Andhra Pradesh                   Rangareddy   5296741.0  2701008.0
# 537  Andhra Pradesh                  Mahbubnagar   4053028.0  2050386.0
# 538  Andhra Pradesh                     Nalgonda   3488809.0  1759772.0
# 539  Andhra Pradesh                     Warangal   3512576.0  1759281.0
# 540  Andhra Pradesh                      Khammam   2797370.0  1390988.0
# 541  Andhra Pradesh                   Srikakulam   2703114.0  1341738.0
# 542  Andhra Pradesh                 Vizianagaram   2344474.0  1161477.0
# ...

# %%
def state_change(df):
    # opening the text file
    with open('Telangana.txt', 'r') as f:
        x = f.read()
    
    x = x.split('\n')

    df.loc[df['District'].isin(x), 'State/UT'] ='Telangana'


    ladd = ["Leh(Ladakh)","Kargil"]
    df.loc[df['District'].isin(ladd) ,'State/UT' ] = 'Laddakh' 
    print()
    return df
    
df = state_change(df)

# %%
df[df['State/UT'] == 'Telangana']
# Out:
#       State/UT     District  Population       Male     Female   Literate  \
# 531  Telangana     Adilabad   2741239.0        NaN  1371642.0  1483347.0
# 532  Telangana    Nizamabad   2551335.0  1250641.0  1300694.0  1389810.0
# 533  Telangana   Karimnagar   3776269.0  1880800.0  1895469.0  2206829.0
# 534  Telangana        Medak   3033288.0  1523030.0  1510258.0  1637137.0
# 535  Telangana    Hyderabad   3943323.0  2018575.0  1924748.0  2892155.0
# 536  Telangana   Rangareddy   5296741.0  2701008.0  2595733.0        NaN
# 537  Telangana  Mahbubnagar   4053028.0  2050386.0  2002642.0  1940646.0
# 538  Telangana     Nalgonda   3488809.0  1759772.0  1729037.0  2001019.0
# 539  Telangana     Warangal   3512576.0  1759281.0  1753295.0  2065023.0
# 540  Telangana      Khammam   2797370.0  1390988.0  1406382.0  1630234.0
#
#      Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 531       856350.0         626997.0               NaN          220248.0
# ...

# %%
df[df['State/UT'] == 'Laddakh']
# Out:
#   State/UT     District  Population     Male   Female  Literate  \
# 2  Laddakh  Leh(Ladakh)    133487.0  78971.0  54516.0   93770.0
# 3  Laddakh       Kargil    140802.0      NaN  63017.0       NaN
#
#    Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 2        62834.0          30936.0           36920.0           17474.0
# 3        56301.0          29935.0           40370.0            7774.0
#
#    Households  Young_and_Adult  Middle_Aged  Senior_Citizen  Age_Not_Stated
# 2     54394.0          70703.0      41515.0             NaN           250.0
# 3     48144.0          87532.0      35561.0         17488.0           221.0

# %%
df['District'].replace({'Leh(Ladakh)':'Leh'}, inplace=True)

# %%
df[df['State/UT'] == 'Laddakh']
# Out:
#   State/UT District  Population     Male   Female  Literate  Literate_Male  \
# 2  Laddakh      Leh    133487.0  78971.0  54516.0   93770.0        62834.0
# 3  Laddakh   Kargil    140802.0      NaN  63017.0       NaN        56301.0
#
#    Literate_Female  Households_Rural  Households_Urban  Households  \
# 2          30936.0           36920.0           17474.0     54394.0
# 3          29935.0           40370.0            7774.0     48144.0
#
#    Young_and_Adult  Middle_Aged  Senior_Citizen  Age_Not_Stated
# 2          70703.0      41515.0             NaN           250.0
# 3          87532.0      35561.0         17488.0           221.0

# %% [markdown]
# # Problem Statement 5: (Find and process Missing Data)

# %%
df.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population          30
# Male                30
# Female              33
# Literate            36
# Literate_Male       31
# Literate_Female     27
# Households_Rural    42
# Households_Urban    33
# Households          32
# Young_and_Adult     31
# Middle_Aged         30
# Senior_Citizen      31
# Age_Not_Stated      35
# dtype: int64

# %%
p=df.isnull().sum()/len(df)*100

# %%
p
# Out:
# State/UT            0.00000
# District            0.00000
# Population          4.68750
# Male                4.68750
# Female              5.15625
# Literate            5.62500
# Literate_Male       4.84375
# Literate_Female     4.21875
# Households_Rural    6.56250
# Households_Urban    5.15625
# Households          5.00000
# Young_and_Adult     4.84375
# Middle_Aged         4.68750
# Senior_Citizen      4.84375
# Age_Not_Stated      5.46875
# dtype: float64

# %%
p1=p.reset_index().rename(columns={0:'percent'}).sort_values('percent')

# %%
p1
# Out:
#                index  percent
# 0           State/UT  0.00000
# 1           District  0.00000
# 7    Literate_Female  4.21875
# 2         Population  4.68750
# 3               Male  4.68750
# 12       Middle_Aged  4.68750
# 6      Literate_Male  4.84375
# 11   Young_and_Adult  4.84375
# 13    Senior_Citizen  4.84375
# 10        Households  5.00000
# 4             Female  5.15625
# 9   Households_Urban  5.15625
# 14    Age_Not_Stated  5.46875
# 5           Literate  5.62500
# 8   Households_Rural  6.56250

# %%
sns.barplot(data = p1 , x = 'percent', y='index')
plt.title("Percentage of Missing Values Before Filling Null Values")
plt.ylabel("Column names")
plt.xlabel("Percentage (%)")
plt.show()

# %%
df['Population'].fillna(df['Male'] + df['Female'], inplace=True)
df['Literate'].fillna(df['Literate_Male'] + df['Literate_Female'], inplace=True)
df['Households'].fillna(df['Households_Rural'] + df['Households_Urban'], inplace=True)
df['Population'].fillna(df['Young_and_Adult'] + df['Middle_Aged'] + df['Senior_Citizen'] + df['Age_Not_Stated'], inplace=True)

# %%
df['Male'].fillna(df['Population'] - df['Female'], inplace=True)
df['Female'].fillna(df['Population'] - df['Male'], inplace=True)
df['Literate_Male'].fillna(df['Literate'] - df['Literate_Female'], inplace=True)
df['Literate_Female'].fillna(df['Literate'] - df['Literate_Male'], inplace=True)
df['Households_Rural'].fillna(df['Households'] - df['Households_Urban'], inplace=True)
df['Households_Urban'].fillna(df['Households'] - df['Households_Rural'], inplace=True)
df['Young_and_Adult'].fillna(df['Population'] - df['Middle_Aged']+df['Senior_Citizen']+df['Age_Not_Stated'], inplace=True)
df['Middle_Aged'].fillna(df['Population'] - df['Young_and_Adult']+df['Senior_Citizen']+df['Age_Not_Stated'], inplace=True)
df['Senior_Citizen'].fillna(df['Population'] - df['Young_and_Adult']+df['Middle_Aged']+df['Age_Not_Stated'], inplace=True)
df['Age_Not_Stated'].fillna(df['Population'] - df['Young_and_Adult']+df['Senior_Citizen']+df['Middle_Aged'], inplace=True)

# %%
df.isnull().sum()
# Out:
# State/UT            0
# District            0
# Population          1
# Male                1
# Female              0
# Literate            2
# Literate_Male       2
# Literate_Female     2
# Households_Rural    6
# Households_Urban    3
# Households          5
# Young_and_Adult     4
# Middle_Aged         6
# Senior_Citizen      8
# Age_Not_Stated      3
# dtype: int64

# %%
p2=(df.isnull().sum()/len(df)*100).reset_index().rename(columns={0:'percent'}).sort_values('percent')

# %%
p2
# Out:
#                index  percent
# 0           State/UT  0.00000
# 1           District  0.00000
# 4             Female  0.00000
# 2         Population  0.15625
# 3               Male  0.15625
# 5           Literate  0.31250
# 6      Literate_Male  0.31250
# 7    Literate_Female  0.31250
# 9   Households_Urban  0.46875
# 14    Age_Not_Stated  0.46875
# 11   Young_and_Adult  0.62500
# 10        Households  0.78125
# 8   Households_Rural  0.93750
# 12       Middle_Aged  0.93750
# 13    Senior_Citizen  1.25000

# %%
sns.barplot(data =p2 , x = 'percent', y='index')
plt.title("Percentage of Missing Values After Filling Null Values")
plt.ylabel("Column names")
plt.xlabel("Percentage (%)")
plt.show()

# %% [raw]
# Changing the state names for uniform Nomenclature in all files
# PONDICHERRY – Puducherry
# ORISSA – Odisha
# NCT OF DELHI – Delhi

# %%
df['State/UT'].value_counts()
# Out:
# Uttar Pradesh                  71
# Madhya Pradesh                 50
# Bihar                          38
# Maharashtra                    35
# Rajasthan                      33
# Tamil Nadu                     32
# Karnataka                      30
# Orissa                         30
# Assam                          27
# Gujarat                        26
# Jharkhand                      24
# Haryana                        21
# Jammu and Kashmir              20
# Punjab                         20
# West Bengal                    19
# Chhattisgarh                   18
# Arunachal Pradesh              16
# Kerala                         14
# Andhra Pradesh                 13
# Uttarakhand                    13
# Himachal Pradesh               12
# Nagaland                       11
# Telangana                      10
# Nct Of Delhi                    9
# Manipur                         9
# Mizoram                         8
# Meghalaya                       7
# ...

# %%
df['State/UT']=df['State/UT'].str.replace('Pondicherry','Puducherry')
df['State/UT']=df['State/UT'].str.replace('Orissa','Odisha')
df['State/UT']=df['State/UT'].str.replace('Nct Of Delhi','Delhi')

# %%
df['State/UT'].value_counts()
# Out:
# Uttar Pradesh                  71
# Madhya Pradesh                 50
# Bihar                          38
# Maharashtra                    35
# Rajasthan                      33
# Tamil Nadu                     32
# Karnataka                      30
# Odisha                         30
# Assam                          27
# Gujarat                        26
# Jharkhand                      24
# Haryana                        21
# Jammu and Kashmir              20
# Punjab                         20
# West Bengal                    19
# Chhattisgarh                   18
# Arunachal Pradesh              16
# Kerala                         14
# Andhra Pradesh                 13
# Uttarakhand                    13
# Himachal Pradesh               12
# Nagaland                       11
# Telangana                      10
# Delhi                           9
# Manipur                         9
# Mizoram                         8
# Meghalaya                       7
# ...

# %% [markdown]
# # Problem Statement 6: (Save Data)

# %%
pwd
# Out:
# 'C:\\Users\\hp\\Downloads'

# %%
df.to_csv(r'C:\Users\hp\Downloads\Clean_Data\census.csv')

# %% [markdown]
# # Problem Statement 7: (Process the relevant data)

# %%
df_house= pd.read_csv('housing.csv', usecols=['State Name','District Name','Rural/Urban','Total Number of households', 'Total Number of Livable',
                          'Total Number of Dilapidated','Latrine_premise'])

# %%
df_house=df_house.rename(columns = {"State Name":'State/UT', 'District Name':'District'})

# %%
df_house.head()
# Out:
#           State/UT District Rural/Urban  Total Number of households  \
# 0  JAMMU & KASHMIR  Kupwara       Rural                         100
# 1  JAMMU & KASHMIR  Kupwara       Total                         100
# 2  JAMMU & KASHMIR  Kupwara       Urban                         100
# 3  JAMMU & KASHMIR   Badgam       Rural                         100
# 4  JAMMU & KASHMIR   Badgam       Total                         100
#
#    Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 0                     58.1                          8.3             48.9
# 1                     57.3                          7.9             50.9
# 2                     49.5                          4.8             70.2
# 3                     46.3                          3.9             83.3
# 4                     44.7                          3.8             84.3

# %%
df_house['State/UT'].value_counts()
# Out:
# UTTAR PRADESH                213
# MADHYA PRADESH               150
# BIHAR                        114
# MAHARASHTRA                  103
# RAJASTHAN                     99
# TAMIL NADU                    95
# KARNATAKA                     90
# ODISHA                        90
# ASSAM                         81
# GUJARAT                       78
# JHARKHAND                     72
# ANDHRA PRADESH                68
# JAMMU & KASHMIR               66
# HARYANA                       63
# PUNJAB                        60
# WEST BENGAL                   56
# CHHATTISGARH                  54
# ARUNACHAL PRADESH             48
# KERALA                        42
# UTTARAKHAND                   39
# HIMACHAL PRADESH              34
# NAGALAND                      33
# MANIPUR                       27
# NCT OF DELHI                  25
# MIZORAM                       24
# MEGHALAYA                     21
# TRIPURA                       12
# SIKKIM                        12
# ...

# %%
df_house['State/UT']=df_house['State/UT'].str.title().str.replace('&','and').str.replace(' Of ', ' of ')
df_house['District']=df_house['District'].str.title().str.replace('&','and').str.replace(' Of', ' of ')

# %%
df_house=state_change(df_house)

# %%
df_house.head()
# Out:
#             State/UT District Rural/Urban  Total Number of households  \
# 0  Jammu and Kashmir  Kupwara       Rural                         100
# 1  Jammu and Kashmir  Kupwara       Total                         100
# 2  Jammu and Kashmir  Kupwara       Urban                         100
# 3  Jammu and Kashmir   Badgam       Rural                         100
# 4  Jammu and Kashmir   Badgam       Total                         100
#
#    Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 0                     58.1                          8.3             48.9
# 1                     57.3                          7.9             50.9
# 2                     49.5                          4.8             70.2
# 3                     46.3                          3.9             83.3
# 4                     44.7                          3.8             84.3

# %%
df_house['State/UT']=df_house['State/UT'].str.replace('Nct of Delhi','Delhi')

# %%
df_house['State/UT'].value_counts()
# Out:
# Uttar Pradesh                  213
# Madhya Pradesh                 150
# Bihar                          114
# Maharashtra                    103
# Rajasthan                       99
# Tamil Nadu                      95
# Karnataka                       90
# Odisha                          90
# Assam                           81
# Gujarat                         78
# Jharkhand                       72
# Haryana                         63
# Jammu and Kashmir               60
# Punjab                          60
# West Bengal                     56
# Chhattisgarh                    54
# Arunachal Pradesh               48
# Kerala                          42
# Andhra Pradesh                  39
# Uttarakhand                     39
# Himachal Pradesh                34
# Nagaland                        33
# Telangana                       29
# Manipur                         27
# Delhi                           25
# Mizoram                         24
# Meghalaya                       21
# ...

# %%
#Mergning the housing and census datasets On ['State/UT','District']
df["State/UT"].nunique()
# Out:
# 37

# %%
df_house['State/UT'].nunique()
# Out:
# 37

# %%
merge_df=pd.merge(left = df,right =df_house,  how='inner', on=['State/UT', 'District'])
merge_df.head()
# Out:
#             State/UT District  Population      Male    Female  Literate  \
# 0  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0  439654.0
# 1  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0  439654.0
# 2  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0  439654.0
# 3  Jammu and Kashmir   Badgam    753745.0  398041.0  355704.0  335649.0
# 4  Jammu and Kashmir   Badgam    753745.0  398041.0  355704.0  335649.0
#
#    Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 0       282823.0         156831.0          158438.0           23226.0
# 1       282823.0         156831.0          158438.0           23226.0
# 2       282823.0         156831.0          158438.0           23226.0
# 3       207741.0         127908.0          160649.0           27190.0
# 4       207741.0         127908.0          160649.0           27190.0
#
#    Households  Young_and_Adult  Middle_Aged  Senior_Citizen  Age_Not_Stated  \
# ...

# %%
merge_df.shape
# Out:
# (1894, 20)

# %%
merge_df.insert(18,'Total % of Livable',merge_df['Total Number of Livable'])
merge_df.insert(20,'Total % of Dilapidated',merge_df['Total Number of Dilapidated'])
merge_df.insert(22,'Total % of Latrine_premise',merge_df['Latrine_premise'])

# %%
merge_df
# Out:
#                          State/UT       District  Population      Male  \
# 0               Jammu and Kashmir        Kupwara    870354.0  474190.0
# 1               Jammu and Kashmir        Kupwara    870354.0  474190.0
# 2               Jammu and Kashmir        Kupwara    870354.0  474190.0
# 3               Jammu and Kashmir         Badgam    753745.0  398041.0
# 4               Jammu and Kashmir         Badgam    753745.0  398041.0
# ...                           ...            ...         ...       ...
# 1889  Andaman and Nicobar Islands       Nicobars     36842.0   20727.0
# 1890  Andaman and Nicobar Islands       Nicobars     36842.0   20727.0
# 1891  Andaman and Nicobar Islands  South Andaman    238142.0  127283.0
# 1892  Andaman and Nicobar Islands  South Andaman    238142.0  127283.0
# 1893  Andaman and Nicobar Islands  South Andaman    238142.0  127283.0
#
#         Female  Literate  Literate_Male  Literate_Female  Households_Rural  \
# ...

# %%
# adding value in rows which have Rural area

cond = merge_df['Rural/Urban'] == 'Rural'

merge_df.loc[cond,'Total Number of Livable'] = merge_df.loc[cond,'Households_Rural'] * merge_df.loc[cond,'Total % of Livable'] /100

merge_df.loc[cond,'Total Number of Dilapidated'] = merge_df.loc[cond,'Households_Rural'] * merge_df.loc[cond,'Total % of Dilapidated'] /100

merge_df.loc[cond, 'Latrine_premise'] = merge_df.loc[cond,'Households_Rural'] * merge_df.loc[cond,'Total % of Latrine_premise'] /100

# %%
# adding value in rows which have Total area

cond = merge_df['Rural/Urban'] == 'Total'

merge_df.loc[cond,'Total Number of Livable'] = merge_df.loc[cond,'Households_Rural'] * merge_df.loc[cond,'Total % of Livable'] /100

merge_df.loc[cond,'Total Number of Dilapidated'] = merge_df.loc[cond,'Households_Rural'] * merge_df.loc[cond,'Total % of Dilapidated'] /100

merge_df.loc[cond, 'Latrine_premise'] = merge_df.loc[cond,'Households_Rural'] * merge_df.loc[cond,'Total % of Latrine_premise'] /100

# %%
merge_df
# Out:
#                          State/UT       District  Population      Male  \
# 0               Jammu and Kashmir        Kupwara    870354.0  474190.0
# 1               Jammu and Kashmir        Kupwara    870354.0  474190.0
# 2               Jammu and Kashmir        Kupwara    870354.0  474190.0
# 3               Jammu and Kashmir         Badgam    753745.0  398041.0
# 4               Jammu and Kashmir         Badgam    753745.0  398041.0
# ...                           ...            ...         ...       ...
# 1889  Andaman and Nicobar Islands       Nicobars     36842.0   20727.0
# 1890  Andaman and Nicobar Islands       Nicobars     36842.0   20727.0
# 1891  Andaman and Nicobar Islands  South Andaman    238142.0  127283.0
# 1892  Andaman and Nicobar Islands  South Andaman    238142.0  127283.0
# 1893  Andaman and Nicobar Islands  South Andaman    238142.0  127283.0
#
#         Female  Literate  Literate_Male  Literate_Female  Households_Rural  \
# ...

# %%
#Creating new data frame with following column
housing=pd.DataFrame(columns=['District' ,'Households_Rural','Households_Rural_Livable','Households_Rural_Dilapidated','Households_Rural_Toilet_Premise','Households_Urban','Households_Urban_Livable','Households_Urban_Dilapidated','Households_Urban_Toilet_Premise'])
housing
# Out:
# Empty DataFrame
# Columns: [District, Households_Rural, Households_Rural_Livable, Households_Rural_Dilapidated, Households_Rural_Toilet_Premise, Households_Urban, Households_Urban_Livable, Households_Urban_Dilapidated, Households_Urban_Toilet_Premise]
# Index: []

# %%
housing['District'] = merge_df['District'].unique()
# adding values in the new data frame
# this will add values for Rural area
housing['Households_Rural'] = merge_df[ merge_df['Rural/Urban' ] == 'Rural' ][ 'Households_Rural' ].reset_index()['Households_Rural']
housing['Households_Rural_Livable'] = merge_df[ merge_df['Rural/Urban' ] == 'Rural' ][ 'Total Number of Livable' ].reset_index()['Total Number of Livable']
housing['Households_Rural_Dilapidated'] = merge_df[ merge_df['Rural/Urban' ] == 'Rural' ][ 'Total Number of Dilapidated' ].reset_index()['Total Number of Dilapidated']
housing['Households_Rural_Toilet_Premise'] = merge_df[ merge_df['Rural/Urban' ] == 'Rural'][ 'Latrine_premise' ].reset_index()['Latrine_premise']

# this will add values for Urban area
housing['Households_Urban'] = merge_df[ merge_df['Rural/Urban'] == 'Urban' ][ 'Households_Urban' ].reset_index()['Households_Urban']
housing['Households_Urban_Livable'] = merge_df[ merge_df['Rural/Urban'] == 'Urban' ][ 'Total Number of Livable' ].reset_index()['Total Number of Livable']
housing['Households_Urban_Dilapidated'] = merge_df[ merge_df['Rural/Urban'] == 'Urban' ][ 'Total Number of Dilapidated' ].reset_index()['Total Number of Dilapidated']
housing['Households_Urban_Toilet_Premise'] = merge_df[ merge_df['Rural/Urban'] == 'Urban' ][ 'Latrine_premise' ].reset_index()['Latrine_premise']

housing.head()
# Out:
#   District  Households_Rural  Households_Rural_Livable  \
# 0  Kupwara          158438.0                 92052.478
# 1   Badgam          160649.0                 74380.487
# 2   Kargil           40370.0                 29591.210
# 3    Punch          132139.0                 78622.705
# 4  Rajouri          196070.0                103721.030
#
#    Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# 0                     13150.354                        77476.182
# 1                      6265.311                       133820.617
# 2                      1412.950                        39078.160
# 3                      3171.336                        18103.043
# 4                      5293.890                        19999.140
#
#    Households_Urban  Households_Urban_Livable  Households_Urban_Dilapidated  \
# 0           23226.0                      49.5                           4.8
# 1           27190.0                      33.8                           2.6
# ...

# %%
housing.to_csv(r'C:\Users\hp\Downloads\Clean_data\housing.csv')

# %% [markdown]
# # Problem Statement 8: (Visualise the housing data)

# %%
merge_df.head()
# Out:
#             State/UT District  Population      Male    Female  Literate  \
# 0  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0  439654.0
# 1  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0  439654.0
# 2  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0  439654.0
# 3  Jammu and Kashmir   Badgam    753745.0  398041.0  355704.0  335649.0
# 4  Jammu and Kashmir   Badgam    753745.0  398041.0  355704.0  335649.0
#
#    Literate_Male  Literate_Female  Households_Rural  Households_Urban  ...  \
# 0       282823.0         156831.0          158438.0           23226.0  ...
# 1       282823.0         156831.0          158438.0           23226.0  ...
# 2       282823.0         156831.0          158438.0           23226.0  ...
# 3       207741.0         127908.0          160649.0           27190.0  ...
# 4       207741.0         127908.0          160649.0           27190.0  ...
#
#    Senior_Citizen  Age_Not_Stated  Rural/Urban  Total Number of households  \
# ...

# %%
merge_df.columns
# Out:
# Index(['State/UT', 'District', 'Population', 'Male', 'Female', 'Literate',
#        'Literate_Male', 'Literate_Female', 'Households_Rural',
#        'Households_Urban', 'Households', 'Young_and_Adult', 'Middle_Aged',
#        'Senior_Citizen', 'Age_Not_Stated', 'Rural/Urban',
#        'Total Number of households', 'Total Number of Livable',
#        'Total % of Livable', 'Total Number of Dilapidated',
#        'Total % of Dilapidated', 'Latrine_premise',
#        'Total % of Latrine_premise'],
#       dtype='object')

# %%
# Number of households for 100 people
plt.figure(figsize=(10, 6))
plt.bar(merge_df['State/UT'], merge_df['Households']/100)
plt.xlabel('State/UT')
plt.ylabel('Number of Households for 100 People')
plt.title('Number of Households for 100 People by State/UT')
plt.xticks(rotation=90)
plt.show()

# %%
# Percentage of households with toilets in premises
plt.figure(figsize=(10, 6))
plt.bar(merge_df['State/UT'], merge_df['Latrine_premise']/merge_df['Households']*100)
plt.xlabel('State/UT')
plt.ylabel('Percentage of Households with Toilets in Premises')
plt.title('Percentage of Households with Toilets in Premises by State/UT')
plt.xticks(rotation=90)
plt.show()

# %%
# Urban to rural population ratio
rural_count = merge_df[merge_df['Rural/Urban'] == 'Rural']['Population'].sum()
urban_count = merge_df[merge_df['Rural/Urban'] == 'Urban']['Population'].sum()
urban_to_rural_ratio = urban_count / rural_count
plt.figure(figsize=(10, 6))
plt.bar(['Rural', 'Urban'], [rural_count, urban_count])
plt.xlabel('Area')
plt.ylabel('Population Count')
plt.title('Urban to Rural Population Ratio')
plt.show()

# %% [markdown]
# # Problem Statement 9: (Inconsistency in different datasets)

# %%
housing.sort_values( by = ['District'], inplace=True )
housing
# Out:
#         District  Households_Rural  Households_Rural_Livable  \
# 523     Adilabad          597466.0                213295.362
# 143         Agra          338475.0                180745.650
# 468    Ahmadabad          353169.0                143033.445
# 513   Ahmadnagar         1041393.0                318666.258
# 278       Aizawl           20570.0                  7117.220
# ..           ...               ...                       ...
# 570       Yadgir          207787.0                106386.944
# 68   Yamunanagar          214464.0                101012.544
# 624        Yanam           15958.0                  3798.004
# 503     Yavatmal          629243.0                295114.967
# 258    Zunheboto           31267.0                 13820.014
#
#      Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# 523                     38835.290                        82450.308
# 143                     25385.625                        45694.125
# ...

# %%
census_sort=df.groupby(by=['State/UT','District']).sum()

# %%
census_sort
# Out:
#                                                         Population       Male  \
# State/UT                    District
# Andaman and Nicobar Islands Nicobars                       36842.0    20727.0
#                             North  AND Middle Andaman     105597.0    54861.0
#                             South Andaman                 238142.0   127283.0
# Andhra Pradesh              Anantapur                    4081148.0  2064495.0
#                             Chittoor                     4174064.0  2090204.0
# ...                                                            ...        ...
# West Bengal                 Paschim Medinipur            5913457.0  3007885.0
#                             Purba Medinipur              5095875.0  2629834.0
#                             Puruliya                     2930115.0  1496996.0
#                             South Twenty Four Parganas   8161961.0  4173778.0
# ...

# %%
housing_sort = housing.groupby( by = ['District'] ).sum()

# %%
housing_sort
# Out:
#              Households_Rural  Households_Rural_Livable  \
# District
# Adilabad             597466.0                213295.362
# Agra                 338475.0                180745.650
# Ahmadabad            353169.0                143033.445
# Ahmadnagar          1041393.0                318666.258
# Aizawl                20570.0                  7117.220
# ...                       ...                       ...
# Yadgir               207787.0                106386.944
# Yamunanagar          214464.0                101012.544
# Yanam                 15958.0                  3798.004
# Yavatmal             629243.0                295114.967
# Zunheboto             31267.0                 13820.014
#
#              Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# District
# Adilabad                        38835.290                        82450.308
# Agra                            25385.625                        45694.125
# ...

# %%
Rural_house_diff = ((abs(housing_sort['Households_Rural'] - census_sort['Households_Rural'])) / census_sort['Households_Rural']) * 100

# %%
Rural_house_diff
# Out:
# State/UT                     District
# Andaman and Nicobar Islands  Nicobars                      100.000000
#                              North  AND Middle Andaman            NaN
#                              South Andaman                 100.000000
# Andhra Pradesh               Anantapur                     100.000000
#                              Chittoor                             inf
#                                                               ...
# West Bengal                  Paschim Medinipur              12.557693
#                              Purba Medinipur                77.127357
#                              Puruliya                        0.000000
#                              South Twenty Four Parganas     13.033321
#                              Uttar Dinajpur                  0.000000
# Name: Households_Rural, Length: 640, dtype: float64

# %%
net = Rural_house_diff[Rural_house_diff > 10].index

# %%
net
# Out:
# MultiIndex([('Andaman and Nicobar Islands',                    'Nicobars'),
#             ('Andaman and Nicobar Islands',               'South Andaman'),
#             (             'Andhra Pradesh',                   'Anantapur'),
#             (             'Andhra Pradesh',                    'Chittoor'),
#             (             'Andhra Pradesh',               'East Godavari'),
#             (             'Andhra Pradesh',                      'Guntur'),
#             (             'Andhra Pradesh',                     'Krishna'),
#             (             'Andhra Pradesh',                     'Kurnool'),
#             (             'Andhra Pradesh',                    'Prakasam'),
#             (             'Andhra Pradesh', 'Sri Potti Sriramulu Nellore'),
#             ...
#             (              'Uttar Pradesh',                    'Pilibhit'),
#             (              'Uttar Pradesh',                  'Rae Bareli'),
# ...

# %% [markdown]
# # Problem Statement 10: (Fix the header)

# %%
hospital_df=pd.read_csv('hospitals.csv')
hospital_df
# Out:
#                    Unnamed: 0     PHC    CHC    SDH     DH Hospitals  \
# 0   Andaman & Nicobar Islands      27      4    NaN      3        34
# 1              Andhra Pradesh    1417    198     31     20      1666
# 2           Arunachal Pradesh     122     62    NaN     15       199
# 3                       Assam    1007    166     14     33      1220
# 4                       Bihar    2007     63     33     43      2146
# 5                  Chandigarh      40      2      1      4        47
# 6                Chhattisgarh     813    166     12     32      1023
# 7        Dadra & Nagar Haveli       9      2      1      1        13
# 8                 Daman & Diu       4      2    NaN      2         8
# 9                       Delhi     534     25      9     47       615
# 10                        Goa      31      4      2      3        40
# 11                    Gujarat    1770    385     44     37      2236
# 12                    Haryana     500    131     24     28       683
# ...

# %%
hospital_df.columns=['State/UT','Number of Primary Health Centers(PHCs)','Community Health Centers(CHCs)',
                  'Sub-District/Divisional Hospitals(SDHs)','District Hospitals(DHs)','Hospitals','HospitalBeds']

# %%
hospital_df
# Out:
#                      State/UT Number of Primary Health Centers(PHCs)  \
# 0   Andaman & Nicobar Islands                                     27
# 1              Andhra Pradesh                                   1417
# 2           Arunachal Pradesh                                    122
# 3                       Assam                                   1007
# 4                       Bihar                                   2007
# 5                  Chandigarh                                     40
# 6                Chhattisgarh                                    813
# 7        Dadra & Nagar Haveli                                      9
# 8                 Daman & Diu                                      4
# 9                       Delhi                                    534
# 10                        Goa                                     31
# 11                    Gujarat                                   1770
# 12                    Haryana                                    500
# ...

# %% [markdown]
# # Problem Statement 11: (Create a function to alter the data to create uniformity)

# %%
housing_df = pd.read_csv('Clean_Data/housing.csv')
census_df= pd.read_csv('Clean_Data/housing.csv')

# %%
housing_df
# Out:
#      Unnamed: 0       District  Households_Rural  Households_Rural_Livable  \
# 0             0        Kupwara          158438.0                 92052.478
# 1             1         Badgam          160649.0                 74380.487
# 2             2         Kargil           40370.0                 29591.210
# 3             3          Punch          132139.0                 78622.705
# 4             4        Rajouri          196070.0                103721.030
# ..          ...            ...               ...                       ...
# 624         624          Yanam           15958.0                  3798.004
# 625         625           Mahe           34901.0                 11691.835
# 626         626       Karaikal               NaN                       NaN
# 627         627       Nicobars               NaN                       NaN
# 628         628  South Andaman               NaN                       NaN
#
# ...

# %%
census_df = pd.read_csv('Clean_Data/census.csv')

# %%
census_df
# Out:
#      Unnamed: 0                     State/UT                   District  \
# 0             0            Jammu and Kashmir                    Kupwara
# 1             1            Jammu and Kashmir                     Badgam
# 2             2                      Laddakh                        Leh
# 3             3                      Laddakh                     Kargil
# 4             4            Jammu and Kashmir                      Punch
# ..          ...                          ...                        ...
# 635         635                   Puducherry                       Mahe
# 636         636                   Puducherry                   Karaikal
# 637         637  Andaman and Nicobar Islands                   Nicobars
# 638         638  Andaman and Nicobar Islands  North  AND Middle Andaman
# 639         639  Andaman and Nicobar Islands              South Andaman
#
#      Population      Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %%
hospital_df['State/UT']
# Out:
# 0     Andaman & Nicobar Islands
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                    Chandigarh
# 6                  Chhattisgarh
# 7          Dadra & Nagar Haveli
# 8                   Daman & Diu
# 9                         Delhi
# 10                          Goa
# 11                      Gujarat
# 12                      Haryana
# 13             Himachal Pradesh
# 14              Jammu & Kashmir
# 15                    Jharkhand
# 16                    Karnataka
# 17                       Kerala
# 18                  Lakshadweep
# 19               Madhya Pradesh
# 20                  Maharashtra
# 21                      Manipur
# 22                    Meghalaya
# 23                      Mizoram
# 24                     Nagaland
# 25                       Odisha
# 26                   Puducherry
# 27                       Punjab
# 28                    Rajasthan
# ...

# %%
def fix_state_names(df):
    # Define the mapping of incorrect names to correct names
    name_mapping = {
        'PONDICHERRY': 'Puducherry',
        'ORISSA': 'Odisha',
        'NCT OF DELHI':'Delhi'
    }
    
    # Replace the incorrect names with the correct names
    df['State/UT'] = df['State/UT'].replace(name_mapping)
    
    return df

# Assuming the dataset is loaded into a DataFrame called 'df'
cleaned_df = fix_state_names(df)

# Save the cleaned data to CSV file
cleaned_df.to_csv('Clean_Data/all_hospitals.csv', index=False)

# %% [markdown]
# # Problem Statement 12: (Analyze Healthcare facility disparity)

# %%
hospital_df.head()
# Out:
#                     State/UT Number of Primary Health Centers(PHCs)  \
# 0  Andaman & Nicobar Islands                                     27
# 1             Andhra Pradesh                                   1417
# 2          Arunachal Pradesh                                    122
# 3                      Assam                                   1007
# 4                      Bihar                                   2007
#
#   Community Health Centers(CHCs) Sub-District/Divisional Hospitals(SDHs)  \
# 0                              4                                     NaN
# 1                            198                                      31
# 2                             62                                     NaN
# 3                            166                                      14
# 4                             63                                      33
#
#   District Hospitals(DHs) Hospitals HospitalBeds
# 0                       3        34         1246
# ...

# %%
census_df.head()
# Out:
#    Unnamed: 0           State/UT District  Population      Male    Female  \
# 0           0  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0
# 1           1  Jammu and Kashmir   Badgam    753745.0  398041.0  355704.0
# 2           2            Laddakh      Leh    133487.0   78971.0   54516.0
# 3           3            Laddakh   Kargil    140802.0   77785.0   63017.0
# 4           4  Jammu and Kashmir    Punch    476835.0  251899.0  224936.0
#
#    Literate  Literate_Male  Literate_Female  Households_Rural  \
# 0  439654.0       282823.0         156831.0          158438.0
# 1  335649.0       207741.0         127908.0          160649.0
# 2   93770.0        62834.0          30936.0           36920.0
# 3   86236.0        56301.0          29935.0           40370.0
# 4  261724.0       163333.0          98391.0          132139.0
#
#    Households_Urban  Households  Young_and_Adult  Middle_Aged  Senior_Citizen  \
# ...

# %%
census_population_df=census_df.groupby(["State/UT"]).sum()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10944\603377697.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   census_population_df=census_df.groupby(["State/UT"]).sum()

# %%
census_population_df.reset_index(drop=False, inplace=True)

# %%
census_population_df
# Out:
#                        State/UT  Unnamed: 0   Population         Male  \
# 0   Andaman and Nicobar Islands        1914     380581.0     202871.0
# 1                Andhra Pradesh        7111   49386799.0   24738068.0
# 2             Arunachal Pradesh        4024    1383727.0     713912.0
# 3                         Assam        8424   31205576.0   15939443.0
# 4                         Bihar        8379  104099452.0   54278157.0
# 5                    Chandigarh          54    1055450.0     580663.0
# 6                  Chhattisgarh        7335   25545198.0   12832895.0
# 7        Dadra and Nagar Haveli         495     343709.0     193760.0
# 8                 Daman and Diu         987     243247.0     150301.0
# 9                         Delhi         837   16787941.0    8987326.0
# 10                          Goa        1169    1458545.0     739140.0
# 11                      Gujarat       12467   60439692.0   31491260.0
# ...

# %%
all_india_population = census_population_df["Population"].sum()
all_india_population
# Out:
# 1209007954.0

# %%
merged_census_hospital = hospital_df.merge(census_population_df, how="inner", on="State/UT")
merged_census_hospital
# Out:
#              State/UT Number of Primary Health Centers(PHCs)  \
# 0      Andhra Pradesh                                   1417
# 1   Arunachal Pradesh                                    122
# 2               Assam                                   1007
# 3               Bihar                                   2007
# 4          Chandigarh                                     40
# 5        Chhattisgarh                                    813
# 6               Delhi                                    534
# 7                 Goa                                     31
# 8             Gujarat                                   1770
# 9             Haryana                                    500
# 10   Himachal Pradesh                                    516
# 11          Jharkhand                                    343
# 12          Karnataka                                   2547
# 13             Kerala                                    933
# ...

# %%
only_hospital = merged_census_hospital[["State/UT","HospitalBeds", "Population"]].copy()
only_hospital.head()
# Out:
#             State/UT HospitalBeds   Population
# 0     Andhra Pradesh        60799   49386799.0
# 1  Arunachal Pradesh         2320    1383727.0
# 2              Assam        19115   31205576.0
# 3              Bihar        17796  104099452.0
# 4         Chandigarh         3756    1055450.0

# %%
only_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State/UT      32 non-null     object
#  1   HospitalBeds  32 non-null     object
#  2   Population    32 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.0+ KB

# %%
only_hospital["HospitalBeds"]=only_hospital["HospitalBeds"].astype(float)

# %%
only_hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State/UT      32 non-null     object
#  1   HospitalBeds  32 non-null     float64
#  2   Population    32 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.0+ KB

# %%
all_india_beds = float("".join(hospital_df.loc[36,"HospitalBeds"].split(",")))
all_india_beds
# Out:
# 739024.0

# %%
only_hospital.set_index("State/UT",inplace=True)
beds=only_hospital
beds["Beds_for_10000"] = only_hospital["HospitalBeds"]/only_hospital["Population"] * 10000
beds.drop(columns=["HospitalBeds","Population"],inplace=True)
beds
# Out:
#                    Beds_for_10000
# State/UT
# Andhra Pradesh          12.310780
# Arunachal Pradesh       16.766313
# Assam                    6.125508
# Bihar                    1.709519
# Chandigarh              35.586717
# Chhattisgarh             5.619060
# Delhi                   12.254034
# Goa                     18.278490
# Gujarat                  6.804965
# Haryana                  5.459646
# Himachal Pradesh        12.682454
# Jharkhand                2.244443
# Karnataka                9.507956
# Kerala                  11.827494
# Lakshadweep             38.775922
# Madhya Pradesh           5.251504
# Maharashtra              6.140014
# Manipur                  8.971235
# Meghalaya               15.453898
# Mizoram                 21.071704
# Nagaland                 9.825616
# Odisha                   3.930270
# Puducherry              35.754552
# Punjab                   4.875765
# Rajasthan                7.563119
# Sikkim                  18.752754
# ...

# %%
national_val=float(all_india_beds)/float(all_india_population)*10000
national_val
# Out:
# 6.1126479569877175

# %%
beds.reset_index(inplace=True)

# %%
beds
# Out:
#              State/UT  Beds_for_10000
# 0      Andhra Pradesh       12.310780
# 1   Arunachal Pradesh       16.766313
# 2               Assam        6.125508
# 3               Bihar        1.709519
# 4          Chandigarh       35.586717
# 5        Chhattisgarh        5.619060
# 6               Delhi       12.254034
# 7                 Goa       18.278490
# 8             Gujarat        6.804965
# 9             Haryana        5.459646
# 10   Himachal Pradesh       12.682454
# 11          Jharkhand        2.244443
# 12          Karnataka        9.507956
# 13             Kerala       11.827494
# 14        Lakshadweep       38.775922
# 15     Madhya Pradesh        5.251504
# 16        Maharashtra        6.140014
# 17            Manipur        8.971235
# 18          Meghalaya       15.453898
# 19            Mizoram       21.071704
# 20           Nagaland        9.825616
# 21             Odisha        3.930270
# 22         Puducherry       35.754552
# 23             Punjab        4.875765
# ...

# %%
plt.figure(figsize=(9, 7))
sns.barplot(x='State/UT', y='Beds_for_10000', data=beds)
plt.axhline(y=national_val, color='black', linestyle='-')
plt.xlabel('State/UT')
plt.ylabel('Number of hospital beds')
plt.title('Number of Hospital beds in each state per 10000 people')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ***Based on the plot, Lakshadweep has the highest no. of beds per 10000 people, whereas the states Bihar, Jharkhand, and Uttar Pradesh have the lowest number of beds for 10000 people.

# %%
only_hospital.sort_values(by="Beds_for_10000").head(3)
# Out:
#          State/UT  Beds_for_10000
# 3           Bihar        1.709519
# 11      Jharkhand        2.244443
# 29  Uttar Pradesh        2.918238

# %% [markdown]
# # Problem Statement 13: (Multi-line header)

# %%
gov_df = pd.read_csv("government_hospitals.csv")
gov_df.head()
# Out:
#            States/UTs Rural hospitals Unnamed: 2 Urban hospitals Unnamed: 4  \
# 0                 NaN             No.       Beds             No.       Beds
# 1      Andhra Pradesh             193       6480              65      16658
# 2  Arunachal Pradesh*             208       2136              10        268
# 3               Assam            1176      10944              50       6198
# 4               Bihar             930       6083             103       5936
#
#         As on
# 0         NaN
# 1  01.01.2017
# 2  31.12.2017
# 3  31.12.2017
# 4  31.12.2016

# %%
col1= ["State/UT","Rural_Government_Hospitals","Rural_Government_Beds","Urban_Government_Hospitals","Urban_Government_Beds","Last_Updated"]
gov_df.columns =col1
gov_df.head()
# Out:
#              State/UT Rural_Government_Hospitals Rural_Government_Beds  \
# 0                 NaN                        No.                  Beds
# 1      Andhra Pradesh                        193                  6480
# 2  Arunachal Pradesh*                        208                  2136
# 3               Assam                       1176                 10944
# 4               Bihar                        930                  6083
#
#   Urban_Government_Hospitals Urban_Government_Beds Last_Updated
# 0                        No.                  Beds          NaN
# 1                         65                 16658   01.01.2017
# 2                         10                   268   31.12.2017
# 3                         50                  6198   31.12.2017
# 4                        103                  5936   31.12.2016

# %%
gov_df.drop(0, inplace=True)
gov_df.head()
# Out:
#              State/UT Rural_Government_Hospitals Rural_Government_Beds  \
# 1      Andhra Pradesh                        193                  6480
# 2  Arunachal Pradesh*                        208                  2136
# 3               Assam                       1176                 10944
# 4               Bihar                        930                  6083
# 5        Chhattisgarh                        169                  5070
#
#   Urban_Government_Hospitals Urban_Government_Beds Last_Updated
# 1                         65                 16658   01.01.2017
# 2                         10                   268   31.12.2017
# 3                         50                  6198   31.12.2017
# 4                        103                  5936   31.12.2016
# 5                         45                  4342   01.01.2016

# %% [markdown]
# # Problem Statement 14: (Data update and code reuse)

# %%
gov_df.head()
# Out:
#              State/UT Rural_Government_Hospitals Rural_Government_Beds  \
# 1      Andhra Pradesh                        193                  6480
# 2  Arunachal Pradesh*                        208                  2136
# 3               Assam                       1176                 10944
# 4               Bihar                        930                  6083
# 5        Chhattisgarh                        169                  5070
#
#   Urban_Government_Hospitals Urban_Government_Beds Last_Updated
# 1                         65                 16658   01.01.2017
# 2                         10                   268   31.12.2017
# 3                         50                  6198   31.12.2017
# 4                        103                  5936   31.12.2016
# 5                         45                  4342   01.01.2016

# %%
gov_df['Last_Updated'] = pd.to_datetime(gov_df['Last_Updated'], format='%d.%m.%Y').dt.strftime('%Y-%m-%d')

# %%
gov_df.head()
# Out:
#              State/UT Rural_Government_Hospitals Rural_Government_Beds  \
# 1      Andhra Pradesh                        193                  6480
# 2  Arunachal Pradesh*                        208                  2136
# 3               Assam                       1176                 10944
# 4               Bihar                        930                  6083
# 5        Chhattisgarh                        169                  5070
#
#   Urban_Government_Hospitals Urban_Government_Beds Last_Updated
# 1                         65                 16658   2017-01-01
# 2                         10                   268   2017-12-31
# 3                         50                  6198   2017-12-31
# 4                        103                  5936   2016-12-31
# 5                         45                  4342   2016-01-01

# %%
gov_df["State/UT"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh*', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa*', 'Gujarat', 'Haryana*', 'Himachal Pradesh*',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka*', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya*',
#        'Mizoram*', 'Nagaland', 'Odisha*', 'Punjab*', 'Rajasthan',
#        'Sikkim*', 'Tamil Nadu*', 'Telangana*', 'Tripura*',
#        'Uttar Pradesh*', 'Uttarakhand', 'West Bengal',
#        'Andaman & Nicobar Islands', 'Chandigarh', 'Dadra & Nagar Haveli*',
#        'Daman & Diu', 'Delhi', 'Lakshadweep', 'Puducherry', 'INDIA'],
#       dtype=object)

# %%
def format_states(df):
    name_correction = {"Pondicherry": "Puducherry", "Nct of Delhi": "Delhi", "Orissa": "Odisha"}
    
    df["State/UT"]=df["State/UT"].str.capitalize()
    df["State/UT"]=df["State/UT"].replace(name_correction)
    df["State/UT"]=df["State/UT"].str.title()
    df['State/UT'] = df['State/UT'].str.replace('&', 'and').str.rstrip('*')
    return df

# %%
#gov_df['State/UT'] = gov_df['State/UT'].apply(fix_state_names)
gov_df = format_states(gov_df)

# %%
gov_df["State/UT"].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Andaman and Nicobar Islands',
#        'Chandigarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'Delhi',
#        'Lakshadweep', 'Puducherry', 'India'], dtype=object)

# %%
gov_df.to_csv(r'C:\Users\hp\Downloads\Clean_data\hospital.csv')

# %% [markdown]
# # Problem Statement 15: (Government healthcare facility disparity)

# %% [markdown]
# ***From the previous analysis it has been found that the states ['Bihar', 'Jharkhand', 'Uttar Pradesh'] has the least number of hospitals wrt its population

# %%
gov_df.dtypes
# Out:
# State/UT                      object
# Rural_Government_Hospitals    object
# Rural_Government_Beds         object
# Urban_Government_Hospitals    object
# Urban_Government_Beds         object
# Last_Updated                  object
# dtype: object

# %%
gov_df['Rural_Government_Hospitals'] =gov_df['Rural_Government_Hospitals'].astype(int)

# %%
gov_df['Urban_Government_Hospitals'] =gov_df['Urban_Government_Hospitals'].astype(int)

# %%
gov_df.dtypes
# Out:
# State/UT                      object
# Rural_Government_Hospitals     int32
# Rural_Government_Beds         object
# Urban_Government_Hospitals     int32
# Urban_Government_Beds         object
# Last_Updated                  object
# dtype: object

# %%
gov_df['Total_Hospitals'] = gov_df['Rural_Government_Hospitals']+gov_df['Urban_Government_Hospitals']

# %%
gov_df.head()
# Out:
#             State/UT  Rural_Government_Hospitals Rural_Government_Beds  \
# 1     Andhra Pradesh                         193                  6480
# 2  Arunachal Pradesh                         208                  2136
# 3              Assam                        1176                 10944
# 4              Bihar                         930                  6083
# 5       Chhattisgarh                         169                  5070
#
#    Urban_Government_Hospitals Urban_Government_Beds Last_Updated  \
# 1                          65                 16658   2017-01-01
# 2                          10                   268   2017-12-31
# 3                          50                  6198   2017-12-31
# 4                         103                  5936   2016-12-31
# 5                          45                  4342   2016-01-01
#
#    Total_Hospitals
# 1              258
# 2              218
# 3             1226
# 4             1033
# 5              214

# %%
gov_df.head()
# Out:
#             State/UT  Rural_Government_Hospitals Rural_Government_Beds  \
# 1     Andhra Pradesh                         193                  6480
# 2  Arunachal Pradesh                         208                  2136
# 3              Assam                        1176                 10944
# 4              Bihar                         930                  6083
# 5       Chhattisgarh                         169                  5070
#
#    Urban_Government_Hospitals Urban_Government_Beds Last_Updated  \
# 1                          65                 16658   2017-01-01
# 2                          10                   268   2017-12-31
# 3                          50                  6198   2017-12-31
# 4                         103                  5936   2016-12-31
# 5                          45                  4342   2016-01-01
#
#    Total_Hospitals
# 1              258
# 2              218
# 3             1226
# 4             1033
# 5              214

# %%
least_hosp= ['Bihar', 'Jharkhand', 'Uttar Pradesh']
least_gov_df = gov_df[gov_df['State/UT'].isin(least_hosp)].sort_values(by='Total_Hospitals').head(1)
least_gov= least_gov_df.iloc[0]['State/UT']
print(f'The state with the least number of govt hospitals among {least_hosp} is {least_gov}.')
# Out:
# The state with the least number of govt hospitals among ['Bihar', 'Jharkhand', 'Uttar Pradesh'] is Jharkhand.

# %% [markdown]
# # Problem Statement 16: (Gap in number of beds)

# %%
hospital_df.head()
# Out:
#                     State/UT Number of Primary Health Centers(PHCs)  \
# 0  Andaman & Nicobar Islands                                     27
# 1             Andhra Pradesh                                   1417
# 2          Arunachal Pradesh                                    122
# 3                      Assam                                   1007
# 4                      Bihar                                   2007
#
#   Community Health Centers(CHCs) Sub-District/Divisional Hospitals(SDHs)  \
# 0                              4                                     NaN
# 1                            198                                      31
# 2                             62                                     NaN
# 3                            166                                      14
# 4                             63                                      33
#
#   District Hospitals(DHs) Hospitals HospitalBeds
# 0                       3        34         1246
# ...

# %%
census_df.head()
# Out:
#    Unnamed: 0           State/UT District  Population      Male    Female  \
# 0           0  Jammu and Kashmir  Kupwara    870354.0  474190.0  396164.0
# 1           1  Jammu and Kashmir   Badgam    753745.0  398041.0  355704.0
# 2           2            Laddakh      Leh    133487.0   78971.0   54516.0
# 3           3            Laddakh   Kargil    140802.0   77785.0   63017.0
# 4           4  Jammu and Kashmir    Punch    476835.0  251899.0  224936.0
#
#    Literate  Literate_Male  Literate_Female  Households_Rural  \
# 0  439654.0       282823.0         156831.0          158438.0
# 1  335649.0       207741.0         127908.0          160649.0
# 2   93770.0        62834.0          30936.0           36920.0
# 3   86236.0        56301.0          29935.0           40370.0
# 4  261724.0       163333.0          98391.0          132139.0
#
#    Households_Urban  Households  Young_and_Adult  Middle_Aged  Senior_Citizen  \
# ...

# %%
actual_beds=hospital_df[['State/UT','HospitalBeds']]

# %%
actual_beds=actual_beds.copy() #just to ignore the warning
actual_beds.sort_values(by=['State/UT'],inplace=True)

# %%
census_df.sort_values(by=['State/UT'],inplace=True)

# %%
actual_beds =actual_beds.copy() #just to ignore the warning
actual_beds.loc[:, 'Expected_beds'] = 3 *census_df['Population'] / 1000

# %%
actual_beds.loc[actual_beds['State/UT'] == 'All India', 'HospitalBeds'] = '739024'
actual_beds['HospitalBeds'] =actual_beds['HospitalBeds'].astype(float)
bed=actual_beds.set_index('State/UT')

# %%
hospital_df.tail()
# Out:
#          State/UT Number of Primary Health Centers(PHCs)  \
# 32        Tripura                                    114
# 33  Uttar Pradesh                                   3277
# 34    Uttarakhand                                    275
# 35    West Bengal                                   1374
# 36      All India                                 29,899
#
#    Community Health Centers(CHCs) Sub-District/Divisional Hospitals(SDHs)  \
# 32                             22                                      12
# 33                            671                                     NaN
# 34                             69                                      19
# 35                            406                                      70
# 36                          5,568                                   1,255
#
#    District Hospitals(DHs) Hospitals HospitalBeds
# 32                       9       157         4895
# 33                     174      4122        58310
# ...

# %%
plt.figure(figsize=(20, 18))
bed.iloc[1:].plot(kind='bar')

plt.xlabel('State/UT')
plt.ylabel('Number of Beds')
plt.title('Actual vs Expected Beds in Each State/UT')
plt.xticks(rotation=90)
plt.legend()
plt.show();

# %% [markdown]
# # Problem Statement 17: (Hospitals required to meet the standards)

# %%
actual_beds2 =actual_beds.copy()
actual_beds2['Difference'] =actual_beds2['Expected_beds']-actual_beds2['HospitalBeds']
actual_beds2
# Out:
#                      State/UT  HospitalBeds  Expected_beds  Difference
# 36                  All India      739024.0       6580.770 -732443.230
# 0   Andaman & Nicobar Islands        1246.0       2611.062    1365.062
# 1              Andhra Pradesh       60799.0       2261.235  -58537.765
# 2           Arunachal Pradesh        2320.0        400.461   -1919.539
# 3                       Assam       19115.0        422.406  -18692.594
# 4                       Bihar       17796.0       1430.505  -16365.495
# 5                  Chandigarh        3756.0       1927.245   -1828.755
# 6                Chhattisgarh       14354.0       1849.305  -12504.695
# 7        Dadra & Nagar Haveli         568.0       3024.117    2456.117
# 8                 Daman & Diu         298.0       1176.696     878.696
# 9                       Delhi       20572.0       3710.487  -16861.513
# 10                        Goa        2666.0        892.338   -1773.662
# ...

# %%
actual_beds2['Avg_beds_per_hospital']=x
actual_beds2['Ratio']=y
actual_beds2
x=round(gov_df['Rural_Government_Beds'].astype(int) +gov_df['Urban_Government_Beds'].astype(int))/(gov_df['Rural_Government_Hospitals'].astype(int)+gov_df['Urban_Government_Hospitals'].astype(int))
x=x.tolist()
y=round(actual_beds2['Difference']/actual_beds2['Avg_beds_per_hospital'])
y=y.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 actual_beds2['Avg_beds_per_hospital']=x
#       2 actual_beds2['Ratio']=y
#       3 actual_beds2
#
# NameError: name 'x' is not defined

# %%
gov=gov_df.copy()
gov=gov.sort_index()
gov
# Out:
#                        State/UT  Rural_Government_Hospitals  \
# 1                Andhra Pradesh                         193
# 2             Arunachal Pradesh                         208
# 3                         Assam                        1176
# 4                         Bihar                         930
# 5                  Chhattisgarh                         169
# 6                           Goa                          17
# 7                       Gujarat                         364
# 8                       Haryana                         609
# 9              Himachal Pradesh                         705
# 10            Jammu and Kashmir                          56
# 11                    Jharkhand                         519
# 12                    Karnataka                        2471
# 13                       Kerala                         981
# 14               Madhya Pradesh                         334
# 15                  Maharashtra                         273
# ...

# %%
actual_beds2['Avg_beds_per_hospital']=x
actual_beds2['Ratio']=y
actual_beds2
# Out:
#                      State/UT  HospitalBeds  Expected_beds  Difference  \
# 36                  All India      739024.0       6580.770 -732443.230
# 0   Andaman & Nicobar Islands        1246.0       2611.062    1365.062
# 1              Andhra Pradesh       60799.0       2261.235  -58537.765
# 2           Arunachal Pradesh        2320.0        400.461   -1919.539
# 3                       Assam       19115.0        422.406  -18692.594
# 4                       Bihar       17796.0       1430.505  -16365.495
# 5                  Chandigarh        3756.0       1927.245   -1828.755
# 6                Chhattisgarh       14354.0       1849.305  -12504.695
# 7        Dadra & Nagar Haveli         568.0       3024.117    2456.117
# 8                 Daman & Diu         298.0       1176.696     878.696
# 9                       Delhi       20572.0       3710.487  -16861.513
# 10                        Goa        2666.0        892.338   -1773.662
# ...

# %%
actual_beds2['Ratio'].abs().iloc[1:].plot(kind='bar', figsize=(10, 8))
plt.xlabel('State/UT')
plt.ylabel('Ratio')
plt.title('Ratio of Beds per Hospital')
plt.xticks(rotation=90)
plt.show();
